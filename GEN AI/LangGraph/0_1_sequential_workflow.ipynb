# %% [markdown]
# ## **LLM LangGraph WorkFlow**

# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash",max_tokens=1056)

# %%
# Define a TypedDict for the state data
class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# The distance between the Earth and the Moon is not constant because the Moon orbits the Earth in an ellipse, not a perfect circle.
#
# However, the **average distance** is approximately:
#
# *   **384,400 kilometers (km)**
# *   **238,900 miles**
#
# To be more precise, the distance varies throughout its orbit:
#
# *   **At its closest point (perigee):** approximately 363,104 km (225,623 miles)
# *   **At its farthest point (apogee):** approximately 405,696 km (252,088 miles)
#
# So, while it varies, the **average of 384,400 km (238,900 miles)** is the most commonly cited figure.
